# %%
from __future__ import print_function
import os
import neat

import pandas as pd
import numpy as np
import random

import torch
import torch.nn as nn
import torch.optim as optim


from explaneat.core.backprop import NeatNet
from explaneat.core import backprop
from explaneat.core.backproppop import BackpropPopulation
from explaneat.visualization import visualize
from explaneat.core.experiment import ExperimentReporter
from explaneat.core.utility import one_hot_encode


from sklearn import datasets
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

from copy import deepcopy

import time
from datetime import datetime


import gzip
try:
    import cPickle as pickle  # pylint: disable=import-error
except ImportError:
    import pickle  # pylint: disable=import-error

# %%
USE_CUDA = torch.cuda.is_available()
# USE_CUDA = False
device = torch.device("cuda:1" if USE_CUDA else "cpu")

# %% [markdown]
# # Breast Cancer Experiment
#
# This experiment (a) test the experimental environment, but is also to evaluate the efficacy of the ExplaNEAT algorithm. Speed is a critical factor, as well as stability of results on population size. Total run time will also be measured

# %% [markdown]
# First, we need to set a random seed and a total stopping point in the number of generations

# %%
my_random_seed = 42
random.seed(my_random_seed)

# %%
def one_hot_encode(vals):
    width = max(vals)
    newVals = []
    for val in vals:
        blank = [0. for _ in range(width + 1)]
        blank[val] = 1.
        newVals.append(blank)
    return np.asarray(newVals)

# %% [markdown]
# ## Dataset
#
# We are going to work with the Iris dataset, which will be loaded from `sklearn`. We want to characterise the efficacy of the algorithm with regards to a mostly untransformed dataset, so we will only normalise the features

# %%
breast_cancer = datasets.load_breast_cancer()
xs_raw = breast_cancer.data[:, :]
scaler = StandardScaler()
scaler.fit(xs_raw)
xs = scaler.transform(xs_raw)
ys = breast_cancer.target.astype(np.float32)
# ys_onehot = one_hot_encode(ys)

# %%
xs = torch.from_numpy(xs).to(device)
ys = torch.from_numpy(ys).to(device)

# %% [markdown]
# Let's have a look at the data we are working with

# %%
ys[18:23]
# Out:
# tensor([0., 1., 1., 1., 0.], device='cuda:1')

# %%
xs[18:20]
# Out:
# tensor([[ 1.6140,  0.6656,  1.5665,  1.7210,  0.1388, -0.0311,  0.7420,  1.1881,
#          -0.8383, -1.2542,  1.2742, -0.3626,  1.4846,  1.5855, -0.1823, -0.3660,
#           0.0669,  0.5538, -0.8454, -0.6801,  2.2884,  0.8472,  2.3691,  2.6675,
#           0.8255,  0.3864,  1.2714,  1.8910, -0.2148, -0.4320],
#         [-0.1668, -1.1472, -0.1857, -0.2520,  0.1017, -0.4369, -0.2782, -0.0286,
#           0.2679, -0.7283, -0.4882, -0.7770, -0.4000, -0.3691,  0.4737, -0.6080,
#          -0.2660,  0.2196, -0.0899, -0.5654, -0.2400, -1.0450, -0.2252, -0.2978,
#           0.5099, -0.4896, -0.1592,  0.2161,  0.1233, -0.6293]],
#        device='cuda:1', dtype=torch.float64)

# %% [markdown]
# ## Performance metric
#
# The NEAT implementation on which ExplaNEAT extends uses a single function call for evaluating fitness. Although this might be reworked for ExplaNEAT to be able to get consistency between the genome-evaluation and the backprop loss function, that can be reviewed later.
#
# This use `Binary Cross Entropy Loss` from `PyTorch`

# %%
def eval_genomes(genomes, config):
    loss = nn.BCELoss()
    loss = loss.to(device)
    for genome_id, genome in genomes:
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        preds = []
        for xi in xs:
            preds.append(net.activate(xi))
        genome.fitness = float(1./loss(torch.tensor(preds).to(device), torch.tensor(ys)))

# %% [markdown]
# ## Base configuration
#
# We are going to create the base configuration according to an external configuration file. Per experiment, we will adjust this, later, but this defines the defaults across all runs.

# %%
config_path = "./config-breast-cancer"
base_config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     config_path)

# %%
base_config.pop_size
# Out:
# 50

# %% [markdown]
# We also want to put a hard limit on how long this can go on for.

# %%
maxNGenerations = 50

# %% [markdown]
# We will create a method to manage the instantiation of a population on the basis of a specific config.

# %%
def instantiate_population(config, xs, ys, saveLocation):

    if not os.path.exists(saveLocation):
        os.makedirs(saveLocation)
        
    config.save(os.path.join(saveLocation, 'config.conf'))

    # Create the population, which is the top-level object for a NEAT run.
    p = BackpropPopulation(config, 
                            xs, 
                            ys, 
                            criterion=nn.BCELoss())

    # Add a stdout reporter to show progress in the terminal.
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)
    p.add_reporter(neat.Checkpointer(5, filename_prefix=str(saveLocation) + "checkpoint-" ))
    bpReporter = backprop.BackpropReporter(True)
    p.add_reporter(bpReporter)
    p.add_reporter(ExperimentReporter(saveLocation))
    
    return p

# %% [markdown]
# # Experiment 1: Vary population size
#
# The first experiment is going to examine the difference in run time different population sizes.

# %%
epoch_points = [10, 25, 50, 100, 150]

# %%
base_config.pop_size
# Out:
# 50

# %%
saveLocationTemplate = './../../data/experiments/breast-cancer/experiment-epochsgpu-{}-{}/'

# %% [markdown]
# ## Start the experiment

# %%
for epochs in epoch_points:
    for iteration_no in range(5):
        my_random_seed += 1
        random.seed(my_random_seed)
        start_time = datetime.now()
        
        print("################################################")
        print("################################################")
        print("Starting epochs {} iteration {}".format(epochs, iteration_no))
        print("Started at {}".format(start_time.strftime("%m/%d/%Y, %H:%M:%S")))
        print("################################################")
        print("################################################")
        
        
        config = deepcopy(base_config)
        
        saveLocation = saveLocationTemplate.format(epochs, iteration_no)
        
        p = instantiate_population(config, xs, ys, saveLocation)
        # Run for up to nGenerations generations.
        winner = p.run(eval_genomes, maxNGenerations, nEpochs = epochs)
        
        g = p.best_genome

        
        end_time = datetime.now()
        
        p.reporters.reporters[2].save_checkpoint(p.config, p.population, p.species, str(p.generation) + "-final")  
        
        winner_net = neat.nn.FeedForwardNetwork.create(winner, config)

        results = []
        for xi, xo in zip(xs, ys):
            output = winner_net.activate(xi)
            results.append([xi, xo, output])

        df = pd.DataFrame(results)
        df.to_csv(os.path.join(saveLocation, 'results.csv'))
        
        ancestry = p.reporters.reporters[3].trace_ancestry_of_species(g.key, p.reproduction.ancestors) 

        ancestors = {
            k: v['genome'] for k, v in p.reporters.reporters[3].ancestry.items()
        }
        
        
        
        ## Save all of these to disc
        filename = 'fullStatus.xplnt'
        print("Saving checkpoint to {0}".format(filename))

        with gzip.open(os.path.join(saveLocation, filename), 'w', compresslevel=5) as f:
            data = (p, g, ancestry, ancestors, random.getstate())
            pickle.dump(data, f, protocol=pickle.HIGHEST_PROTOCOL)
    
#         visualize.create_ancestry_video(p.config, 
#                                         g, 
#                                         ancestry, 
#                                         ancestors, 
#                                         p.reporters.reporters[1], 
#                                         pathname=saveLocation)
        print("################################################")
        print("################################################")
        print("Have finished epochs {} iteration {}".format(epochs, iteration_no))
        print("Started at {}".format(start_time.strftime("%m/%d/%Y, %H:%M:%S")))
        print("The time is {}".format(end_time.strftime("%m/%d/%Y, %H:%M:%S")))
        print("################################################")
        print("################################################")
# Out:
# ################################################
# ################################################
# Starting epochs 10 iteration 0
# Started at 07/11/2019, 03:49:07
# ################################################
# ################################################
#
#  ****** Running generation 0 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(1.2379, grad_fn=<DivBackward0>)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if __name__ == '__main__':
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:2016: UserWarning: Using a target size (torch.Size([569])) that is different to the input size (torch.Size([569, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Population's average fitness: 0.19638 stdev: 0.17047
# Best fitness: 0.80782 - size: (1, 30) - species 2 - id 48
# ending generation %s
# Average adjusted fitness: 0.122
# Mean genetic distance 3.884, standard deviation 1.786
# Population of 51 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    13      0.3    0.145     0
#      2    0    16      0.8    0.193     0
#      3    0    14      0.6    0.137     0
#      4    0     5      0.2    0.074     0
#      5    0     3      0.1    0.059     0
# Total extinctions: 0
# Generation time: 602.033 sec
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-0
#
#  ****** Running generation 1 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.6263, grad_fn=<DivBackward0>)
# Population's average fitness: 0.41765 stdev: 0.31135
# Best fitness: 1.59647 - size: (1, 29) - species 2 - id 80
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f3edc0455c0>, 'fitness': 1.5964744091033936, 'firstDerivatives': [0.0, 0.7886550426483154], 'secondDerivatives': [0.0, 0.7886550426483154]}
# Key: 80
# Fitness: 1.5964744091033936
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=True)
# 	DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# 	DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# 	DefaultConnectionGene(key=(-27, 0), weight=0.6528860330581665, enabled=True)
# 	DefaultConnectionGene(key=(-26, 0), weight=-0.843734622001648, enabled=True)
# 	DefaultConnectionGene(key=(-25, 0), weight=0.3992113769054413, enabled=True)
# 	DefaultConnectionGene(key=(-24, 0), weight=0.45708030462265015, enabled=True)
# 	DefaultConnectionGene(key=(-23, 0), weight=-0.14505530893802643, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# 	DefaultConnectionGene(key=(-19, 0), weight=1.395400047302246, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=-0.11023660004138947, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=1.5401889085769653, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# 	DefaultConnectionGene(key=(-14, 0), weight=0.30093303322792053, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=-0.3302644193172455, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=-1.1728407144546509, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=-0.1315319985151291, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-0.581287145614624, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=-1.8188481330871582, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=-0.15358515083789825, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-0.4812641143798828, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=0.504030168056488, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-1, 0)    DefaultConnectionGene(key=(-1, 0), weight=0.504030168056488, enabled=True)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# (-3, 0)    DefaultConnectionGene(key=(-3, 0), weight=-0.4812641143798828, enabled=True)
# (-5, 0)    DefaultConnectionGene(key=(-5, 0), weight=-0.15358515083789825, enabled=True)
# (-6, 0)    DefaultConnectionGene(key=(-6, 0), weight=-1.8188481330871582, enabled=True)
# (-7, 0)    DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# (-8, 0)    DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# (-9, 0)    DefaultConnectionGene(key=(-9, 0), weight=-0.581287145614624, enabled=True)
# (-10, 0)    DefaultConnectionGene(key=(-10, 0), weight=-0.1315319985151291, enabled=True)
# (-11, 0)    DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# (-12, 0)    DefaultConnectionGene(key=(-12, 0), weight=-1.1728407144546509, enabled=True)
# (-13, 0)    DefaultConnectionGene(key=(-13, 0), weight=-0.3302644193172455, enabled=True)
# (-14, 0)    DefaultConnectionGene(key=(-14, 0), weight=0.30093303322792053, enabled=True)
# (-15, 0)    DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# (-16, 0)    DefaultConnectionGene(key=(-16, 0), weight=1.5401889085769653, enabled=True)
# (-17, 0)    DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# (-18, 0)    DefaultConnectionGene(key=(-18, 0), weight=-0.11023660004138947, enabled=True)
# (-19, 0)    DefaultConnectionGene(key=(-19, 0), weight=1.395400047302246, enabled=True)
# (-20, 0)    DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# (-21, 0)    DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# (-22, 0)    DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# (-23, 0)    DefaultConnectionGene(key=(-23, 0), weight=-0.14505530893802643, enabled=True)
# (-24, 0)    DefaultConnectionGene(key=(-24, 0), weight=0.45708030462265015, enabled=True)
# (-25, 0)    DefaultConnectionGene(key=(-25, 0), weight=0.3992113769054413, enabled=True)
# (-26, 0)    DefaultConnectionGene(key=(-26, 0), weight=-0.843734622001648, enabled=True)
# (-27, 0)    DefaultConnectionGene(key=(-27, 0), weight=0.6528860330581665, enabled=True)
# (-28, 0)    DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# (-29, 0)    DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# (-30, 0)    DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.158
# Mean genetic distance 3.729, standard deviation 1.818
# Population of 51 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    12      0.8    0.179     0
#      2    1    20      1.6    0.367     0
#      3    1    13      0.9    0.194     0
#      4    1     4      0.2    0.039     1
#      5    1     2      0.1    0.011     0
# Total extinctions: 0
# Generation time: 620.179 sec (611.106 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-1
#
#  ****** Running generation 2 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.4789, grad_fn=<DivBackward0>)
# Population's average fitness: 0.78594 stdev: 0.46857
# Best fitness: 2.08729 - size: (1, 28) - species 2 - id 128
# ending generation %s
# Average adjusted fitness: 0.247
# Mean genetic distance 3.473, standard deviation 1.902
# Population of 51 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    13      1.1    0.331     0
#      2    2    19      2.1    0.489     0
#      3    2    14      1.4    0.325     0
#      4    2     3      0.2    0.068     0
#      5    2     2      0.1    0.023     1
# Total extinctions: 0
# Generation time: 582.663 sec (601.625 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-2
#
#  ****** Running generation 3 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.4692, grad_fn=<DivBackward0>)
# Population's average fitness: 1.13550 stdev: 0.56582
# Best fitness: 2.13065 - size: (1, 28) - species 2 - id 164
# ending generation %s
# Average adjusted fitness: 0.337
# Mean genetic distance 3.513, standard deviation 1.942
# Population of 51 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    14      1.9    0.516     0
#      2    3    20      2.1    0.688     0
#      3    3    13      1.6    0.429     0
#      4    3     2      0.2    0.053     0
#      5    3     2      0.1    0.000     2
# Total extinctions: 0
# Generation time: 591.226 sec (599.025 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-3
#
#  ****** Running generation 4 ******
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2766, grad_fn=<DivBackward0>)
# Population's average fitness: 1.73664 stdev: 0.74985
# Best fitness: 3.61596 - size: (1, 27) - species 2 - id 200
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f3edc091668>, 'fitness': 3.6159563064575195, 'firstDerivatives': [0.0, 0.7886550426483154, 0.49081850051879883, 0.04335618019104004, 1.485307216644287], 'secondDerivatives': [0.0, 0.7886550426483154, -0.2978365421295166, -0.4474623203277588, 1.441951036453247]}
# Key: 200
# Fitness: 3.6159563064575195
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=True)
# 	DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# 	DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# 	DefaultConnectionGene(key=(-27, 0), weight=-0.41325443983078003, enabled=True)
# 	DefaultConnectionGene(key=(-25, 0), weight=-0.5217965841293335, enabled=True)
# 	DefaultConnectionGene(key=(-24, 0), weight=-1.1259959936141968, enabled=True)
# 	DefaultConnectionGene(key=(-23, 0), weight=-2.1757988929748535, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# 	DefaultConnectionGene(key=(-19, 0), weight=1.395400047302246, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=-0.688518226146698, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# 	DefaultConnectionGene(key=(-14, 0), weight=0.2846299111843109, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=-0.11875329166650772, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=-0.7028369307518005, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=0.534806489944458, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-0.037489861249923706, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=0.07813716679811478, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=0.6462366580963135, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=-0.46605825424194336, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=-0.16167423129081726, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-1, 0)    DefaultConnectionGene(key=(-1, 0), weight=-0.16167423129081726, enabled=True)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=-0.46605825424194336, enabled=True)
# (-5, 0)    DefaultConnectionGene(key=(-5, 0), weight=0.6462366580963135, enabled=True)
# (-6, 0)    DefaultConnectionGene(key=(-6, 0), weight=0.07813716679811478, enabled=True)
# (-7, 0)    DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# (-8, 0)    DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# (-9, 0)    DefaultConnectionGene(key=(-9, 0), weight=-0.037489861249923706, enabled=True)
# (-10, 0)    DefaultConnectionGene(key=(-10, 0), weight=0.534806489944458, enabled=True)
# (-11, 0)    DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# (-12, 0)    DefaultConnectionGene(key=(-12, 0), weight=-0.7028369307518005, enabled=True)
# (-13, 0)    DefaultConnectionGene(key=(-13, 0), weight=-0.11875329166650772, enabled=True)
# (-14, 0)    DefaultConnectionGene(key=(-14, 0), weight=0.2846299111843109, enabled=True)
# (-15, 0)    DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# (-16, 0)    DefaultConnectionGene(key=(-16, 0), weight=-0.688518226146698, enabled=True)
# (-17, 0)    DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# (-19, 0)    DefaultConnectionGene(key=(-19, 0), weight=1.395400047302246, enabled=True)
# (-20, 0)    DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# (-21, 0)    DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# (-22, 0)    DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# (-24, 0)    DefaultConnectionGene(key=(-24, 0), weight=-1.1259959936141968, enabled=True)
# (-25, 0)    DefaultConnectionGene(key=(-25, 0), weight=-0.5217965841293335, enabled=True)
# (-27, 0)    DefaultConnectionGene(key=(-27, 0), weight=-0.41325443983078003, enabled=True)
# (-28, 0)    DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# (-29, 0)    DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# (-30, 0)    DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=True)
# (-23, 0)    DefaultConnectionGene(key=(-23, 0), weight=-2.1757988929748535, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.297
# Mean genetic distance 3.247, standard deviation 1.887
# Population of 50 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    14      2.2    0.437     0
#      2    4    19      3.6    0.621     0
#      3    4    13      2.1    0.392     0
#      4    4     2      0.2    0.033     1
#      5    4     2      0.1    0.000     3
# Total extinctions: 0
# Generation time: 578.889 sec (594.998 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-4
#
#  ****** Running generation 5 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2766, grad_fn=<DivBackward0>)
# Population's average fitness: 2.00311 stdev: 0.90077
# Best fitness: 3.61596 - size: (1, 27) - species 2 - id 200
# ending generation %s
# Average adjusted fitness: 0.346
# Mean genetic distance 3.249, standard deviation 1.893
# Population of 50 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    14      3.0    0.511     0
#      2    5    19      3.6    0.730     1
#      3    5    13      2.4    0.457     0
#      4    5     2      0.2    0.033     2
#      5    5     2      0.1    0.000     4
# Total extinctions: 0
# Generation time: 561.091 sec (589.347 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-5
#
#  ****** Running generation 6 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2348, grad_fn=<DivBackward0>)
# Population's average fitness: 2.61311 stdev: 0.96357
# Best fitness: 4.25621 - size: (1, 26) - species 2 - id 281
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f3ed5512c50>, 'fitness': 4.256211757659912, 'firstDerivatives': [0.0, 0.7886550426483154, 0.49081850051879883, 0.04335618019104004, 1.485307216644287, 0.0, 0.6402554512023926], 'secondDerivatives': [0.0, 0.7886550426483154, -0.2978365421295166, -0.4474623203277588, 1.441951036453247, -1.485307216644287, 0.6402554512023926]}
# Key: 281
# Fitness: 4.256211757659912
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=True)
# 	DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# 	DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# 	DefaultConnectionGene(key=(-27, 0), weight=-0.41325443983078003, enabled=True)
# 	DefaultConnectionGene(key=(-25, 0), weight=-0.5217965841293335, enabled=True)
# 	DefaultConnectionGene(key=(-24, 0), weight=-1.1259959936141968, enabled=True)
# 	DefaultConnectionGene(key=(-23, 0), weight=-2.1757988929748535, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# 	DefaultConnectionGene(key=(-19, 0), weight=1.395400047302246, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=-0.688518226146698, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# 	DefaultConnectionGene(key=(-14, 0), weight=0.2846299111843109, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=-0.3302644193172455, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=0.534806489944458, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-0.037489861249923706, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=0.07813716679811478, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=0.6462366580963135, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=-0.46605825424194336, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=0.504030168056488, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-1, 0)    DefaultConnectionGene(key=(-1, 0), weight=0.504030168056488, enabled=True)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=-0.46605825424194336, enabled=True)
# (-5, 0)    DefaultConnectionGene(key=(-5, 0), weight=0.6462366580963135, enabled=True)
# (-6, 0)    DefaultConnectionGene(key=(-6, 0), weight=0.07813716679811478, enabled=True)
# (-7, 0)    DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# (-8, 0)    DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# (-9, 0)    DefaultConnectionGene(key=(-9, 0), weight=-0.037489861249923706, enabled=True)
# (-10, 0)    DefaultConnectionGene(key=(-10, 0), weight=0.534806489944458, enabled=True)
# (-11, 0)    DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# (-13, 0)    DefaultConnectionGene(key=(-13, 0), weight=-0.3302644193172455, enabled=True)
# (-14, 0)    DefaultConnectionGene(key=(-14, 0), weight=0.2846299111843109, enabled=True)
# (-15, 0)    DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# (-16, 0)    DefaultConnectionGene(key=(-16, 0), weight=-0.688518226146698, enabled=True)
# (-17, 0)    DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# (-19, 0)    DefaultConnectionGene(key=(-19, 0), weight=1.395400047302246, enabled=True)
# (-20, 0)    DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# (-21, 0)    DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# (-22, 0)    DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# (-24, 0)    DefaultConnectionGene(key=(-24, 0), weight=-1.1259959936141968, enabled=True)
# (-25, 0)    DefaultConnectionGene(key=(-25, 0), weight=-0.5217965841293335, enabled=True)
# (-27, 0)    DefaultConnectionGene(key=(-27, 0), weight=-0.41325443983078003, enabled=True)
# (-28, 0)    DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# (-29, 0)    DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# (-30, 0)    DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=True)
# (-23, 0)    DefaultConnectionGene(key=(-23, 0), weight=-2.1757988929748535, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.390
# Mean genetic distance 3.244, standard deviation 1.750
# Population of 50 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    14      3.6    0.613     0
#      2    6    19      4.3    0.761     0
#      3    6    13      3.1    0.546     0
#      4    6     2      0.2    0.028     3
#      5    6     2      0.1    0.000     5
# Total extinctions: 0
# Generation time: 552.802 sec (584.126 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-6
#
#  ****** Running generation 7 ******
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2195, grad_fn=<DivBackward0>)
# Population's average fitness: 2.79740 stdev: 1.08741
# Best fitness: 4.55680 - size: (2, 27) - species 2 - id 334
# ending generation %s
# Average adjusted fitness: 0.391
# Mean genetic distance 3.129, standard deviation 1.623
# Population of 50 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    14      3.6    0.600     1
#      2    7    19      4.6    0.755     0
#      3    7    13      3.5    0.572     0
#      4    7     2      0.2    0.026     4
#      5    7     2      0.1    0.000     6
# Total extinctions: 0
# Generation time: 550.358 sec (579.905 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-7
#
#  ****** Running generation 8 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2179, grad_fn=<DivBackward0>)
# Population's average fitness: 3.18843 stdev: 1.19442
# Best fitness: 4.58934 - size: (2, 25) - species 2 - id 373
# ending generation %s
# Average adjusted fitness: 0.446
# Mean genetic distance 3.027, standard deviation 1.582
# Population of 51 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    15      4.2    0.711     0
#      2    8    18      4.6    0.830     0
#      3    8    14      4.0    0.661     0
#      4    8     2      0.2    0.026     5
#      5    8     2      0.1    0.000     7
# Total extinctions: 0
# Generation time: 551.241 sec (576.720 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-8
#
#  ****** Running generation 9 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.1948, grad_fn=<DivBackward0>)
# Population's average fitness: 3.09615 stdev: 1.53358
# Best fitness: 5.13269 - size: (1, 25) - species 2 - id 410
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f3ed5396a90>, 'fitness': 5.132694721221924, 'firstDerivatives': [0.0, 0.7886550426483154, 0.49081850051879883, 0.04335618019104004, 1.485307216644287, 0.0, 0.6402554512023926, 0.30058908462524414, 0.03253889083862305, 0.5433549880981445], 'secondDerivatives': [0.0, 0.7886550426483154, -0.2978365421295166, -0.4474623203277588, 1.441951036453247, -1.485307216644287, 0.6402554512023926, -0.33966636657714844, -0.2680501937866211, 0.5108160972595215]}
# Key: 410
# Fitness: 5.132694721221924
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=True)
# 	DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# 	DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# 	DefaultConnectionGene(key=(-27, 0), weight=-0.41325443983078003, enabled=True)
# 	DefaultConnectionGene(key=(-25, 0), weight=-0.5217965841293335, enabled=True)
# 	DefaultConnectionGene(key=(-24, 0), weight=-1.1259959936141968, enabled=True)
# 	DefaultConnectionGene(key=(-23, 0), weight=-2.1757988929748535, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# 	DefaultConnectionGene(key=(-19, 0), weight=1.395400047302246, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=-0.32294169068336487, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=-0.688518226146698, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=-0.11875329166650772, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=-0.7028369307518005, enabled=False)
# 	DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=0.534806489944458, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-0.037489861249923706, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=0.07813716679811478, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=-0.46605825424194336, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=-0.16167423129081726, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-1, 0)    DefaultConnectionGene(key=(-1, 0), weight=-0.16167423129081726, enabled=True)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=-0.46605825424194336, enabled=True)
# (-6, 0)    DefaultConnectionGene(key=(-6, 0), weight=0.07813716679811478, enabled=True)
# (-7, 0)    DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# (-8, 0)    DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# (-9, 0)    DefaultConnectionGene(key=(-9, 0), weight=-0.037489861249923706, enabled=True)
# (-10, 0)    DefaultConnectionGene(key=(-10, 0), weight=0.534806489944458, enabled=True)
# (-11, 0)    DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# (-12, 0)    DefaultConnectionGene(key=(-12, 0), weight=-0.7028369307518005, enabled=False)
# (-13, 0)    DefaultConnectionGene(key=(-13, 0), weight=-0.11875329166650772, enabled=True)
# (-15, 0)    DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# (-16, 0)    DefaultConnectionGene(key=(-16, 0), weight=-0.688518226146698, enabled=True)
# (-17, 0)    DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# (-19, 0)    DefaultConnectionGene(key=(-19, 0), weight=1.395400047302246, enabled=True)
# (-20, 0)    DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# (-21, 0)    DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# (-22, 0)    DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# (-24, 0)    DefaultConnectionGene(key=(-24, 0), weight=-1.1259959936141968, enabled=True)
# (-25, 0)    DefaultConnectionGene(key=(-25, 0), weight=-0.5217965841293335, enabled=True)
# (-27, 0)    DefaultConnectionGene(key=(-27, 0), weight=-0.41325443983078003, enabled=True)
# (-28, 0)    DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# (-29, 0)    DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# (-30, 0)    DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=True)
# (-23, 0)    DefaultConnectionGene(key=(-23, 0), weight=-2.1757988929748535, enabled=True)
# (-18, 0)    DefaultConnectionGene(key=(-18, 0), weight=-0.32294169068336487, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.391
# Mean genetic distance 3.178, standard deviation 1.589
# Population of 49 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    13      4.2    0.524     1
#      2    9    18      5.1    0.778     0
#      3    9    14      4.2    0.614     0
#      4    9     2      0.2    0.032     6
#      5    9     2      0.1    0.009     8
# Total extinctions: 0
# Generation time: 561.024 sec (575.151 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-9
#
#  ****** Running generation 10 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.1748, grad_fn=<DivBackward0>)
# Population's average fitness: 3.29852 stdev: 1.79409
# Best fitness: 5.72008 - size: (2, 25) - species 2 - id 444
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f3ed5280588>, 'fitness': 5.7200798988342285, 'firstDerivatives': [0.0, 0.7886550426483154, 0.49081850051879883, 0.04335618019104004, 1.485307216644287, 0.0, 0.6402554512023926, 0.30058908462524414, 0.03253889083862305, 0.5433549880981445, 0.5873851776123047], 'secondDerivatives': [0.0, 0.7886550426483154, -0.2978365421295166, -0.4474623203277588, 1.441951036453247, -1.485307216644287, 0.6402554512023926, -0.33966636657714844, -0.2680501937866211, 0.5108160972595215, 0.044030189514160156]}
# Key: 444
# Fitness: 5.7200798988342285
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# 	208 DefaultNodeGene(key=208, bias=-1.0609382390975952, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=True)
# 	DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# 	DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# 	DefaultConnectionGene(key=(-27, 0), weight=-0.41325443983078003, enabled=True)
# 	DefaultConnectionGene(key=(-25, 0), weight=-0.5217965841293335, enabled=True)
# 	DefaultConnectionGene(key=(-24, 0), weight=-1.1259959936141968, enabled=False)
# 	DefaultConnectionGene(key=(-23, 0), weight=-2.1757988929748535, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=-0.32294169068336487, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=-0.688518226146698, enabled=False)
# 	DefaultConnectionGene(key=(-16, 208), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=-0.11875329166650772, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=-0.7028369307518005, enabled=False)
# 	DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=0.534806489944458, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-0.037489861249923706, enabled=True)
# 	DefaultConnectionGene(key=(-9, 208), weight=-0.9244194030761719, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=0.07813716679811478, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=-0.46605825424194336, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=-0.16167423129081726, enabled=True)
# 	DefaultConnectionGene(key=(208, 0), weight=-0.688518226146698, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# 208    DefaultNodeGene(key=208, bias=-1.0609382390975952, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-1, 0)    DefaultConnectionGene(key=(-1, 0), weight=-0.16167423129081726, enabled=True)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=-0.46605825424194336, enabled=True)
# (-6, 0)    DefaultConnectionGene(key=(-6, 0), weight=0.07813716679811478, enabled=True)
# (-7, 0)    DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# (-8, 0)    DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# (-9, 0)    DefaultConnectionGene(key=(-9, 0), weight=-0.037489861249923706, enabled=True)
# (-10, 0)    DefaultConnectionGene(key=(-10, 0), weight=0.534806489944458, enabled=True)
# (-11, 0)    DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# (-12, 0)    DefaultConnectionGene(key=(-12, 0), weight=-0.7028369307518005, enabled=False)
# (-13, 0)    DefaultConnectionGene(key=(-13, 0), weight=-0.11875329166650772, enabled=True)
# (-15, 0)    DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# (-16, 0)    DefaultConnectionGene(key=(-16, 0), weight=-0.688518226146698, enabled=False)
# (-17, 0)    DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# (-20, 0)    DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# (-21, 0)    DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# (-22, 0)    DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# (-24, 0)    DefaultConnectionGene(key=(-24, 0), weight=-1.1259959936141968, enabled=False)
# (-25, 0)    DefaultConnectionGene(key=(-25, 0), weight=-0.5217965841293335, enabled=True)
# (-27, 0)    DefaultConnectionGene(key=(-27, 0), weight=-0.41325443983078003, enabled=True)
# (-28, 0)    DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# (-29, 0)    DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# (-30, 0)    DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=True)
# (-23, 0)    DefaultConnectionGene(key=(-23, 0), weight=-2.1757988929748535, enabled=True)
# (-18, 0)    DefaultConnectionGene(key=(-18, 0), weight=-0.32294169068336487, enabled=True)
# (-16, 208)    DefaultConnectionGene(key=(-16, 208), weight=1.0, enabled=True)
# (208, 0)    DefaultConnectionGene(key=(208, 0), weight=-0.688518226146698, enabled=True)
# (-9, 208)    DefaultConnectionGene(key=(-9, 208), weight=-0.9244194030761719, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.367
# Mean genetic distance 3.056, standard deviation 1.645
# Population of 51 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    14      4.2    0.497     2
#      2   10    20      5.7    0.827     0
#      3   10    13      4.2    0.473     1
#      4   10     2      0.2    0.029     7
#      5   10     2      0.1    0.008     9
# Total extinctions: 0
# Generation time: 532.963 sec (568.244 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-10
#
#  ****** Running generation 11 ******
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.1517, grad_fn=<DivBackward0>)
# Population's average fitness: 3.87100 stdev: 1.60771
# Best fitness: 6.59242 - size: (2, 21) - species 2 - id 494
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f3ed52f7780>, 'fitness': 6.592418670654297, 'firstDerivatives': [0.0, 0.7886550426483154, 0.49081850051879883, 0.04335618019104004, 1.485307216644287, 0.0, 0.6402554512023926, 0.30058908462524414, 0.03253889083862305, 0.5433549880981445, 0.5873851776123047, 0.8723387718200684], 'secondDerivatives': [0.0, 0.7886550426483154, -0.2978365421295166, -0.4474623203277588, 1.441951036453247, -1.485307216644287, 0.6402554512023926, -0.33966636657714844, -0.2680501937866211, 0.5108160972595215, 0.044030189514160156, 0.28495359420776367]}
# Key: 494
# Fitness: 6.592418670654297
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# 	208 DefaultNodeGene(key=208, bias=-1.0609382390975952, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=False)
# 	DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# 	DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# 	DefaultConnectionGene(key=(-27, 0), weight=-0.41325443983078003, enabled=False)
# 	DefaultConnectionGene(key=(-25, 0), weight=-0.5217965841293335, enabled=True)
# 	DefaultConnectionGene(key=(-24, 0), weight=-1.1259959936141968, enabled=False)
# 	DefaultConnectionGene(key=(-23, 0), weight=-2.1757988929748535, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=-0.32294169068336487, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=-0.688518226146698, enabled=False)
# 	DefaultConnectionGene(key=(-16, 208), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=-0.11875329166650772, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=-0.7028369307518005, enabled=False)
# 	DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=0.534806489944458, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-0.037489861249923706, enabled=True)
# 	DefaultConnectionGene(key=(-9, 208), weight=-0.9244194030761719, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=0.07813716679811478, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=-0.46605825424194336, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# 	DefaultConnectionGene(key=(208, 0), weight=-0.688518226146698, enabled=False)
# Nodes
# 0    DefaultNodeGene(key=0, bias=0.43824145197868347, response=1.0, activation=sigmoid, aggregation=sum)
# 208    DefaultNodeGene(key=208, bias=-1.0609382390975952, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=1.0982424020767212, enabled=True)
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=-0.46605825424194336, enabled=True)
# (-6, 0)    DefaultConnectionGene(key=(-6, 0), weight=0.07813716679811478, enabled=True)
# (-7, 0)    DefaultConnectionGene(key=(-7, 0), weight=-0.6354101896286011, enabled=True)
# (-8, 0)    DefaultConnectionGene(key=(-8, 0), weight=-0.6082102060317993, enabled=True)
# (-9, 0)    DefaultConnectionGene(key=(-9, 0), weight=-0.037489861249923706, enabled=True)
# (-10, 0)    DefaultConnectionGene(key=(-10, 0), weight=0.534806489944458, enabled=True)
# (-11, 0)    DefaultConnectionGene(key=(-11, 0), weight=-1.3656576871871948, enabled=True)
# (-12, 0)    DefaultConnectionGene(key=(-12, 0), weight=-0.7028369307518005, enabled=False)
# (-13, 0)    DefaultConnectionGene(key=(-13, 0), weight=-0.11875329166650772, enabled=True)
# (-15, 0)    DefaultConnectionGene(key=(-15, 0), weight=-0.17723196744918823, enabled=True)
# (-16, 0)    DefaultConnectionGene(key=(-16, 0), weight=-0.688518226146698, enabled=False)
# (-17, 0)    DefaultConnectionGene(key=(-17, 0), weight=-0.21049749851226807, enabled=True)
# (-20, 0)    DefaultConnectionGene(key=(-20, 0), weight=0.6951144337654114, enabled=True)
# (-21, 0)    DefaultConnectionGene(key=(-21, 0), weight=-0.7164230346679688, enabled=True)
# (-22, 0)    DefaultConnectionGene(key=(-22, 0), weight=-2.195161819458008, enabled=True)
# (-24, 0)    DefaultConnectionGene(key=(-24, 0), weight=-1.1259959936141968, enabled=False)
# (-25, 0)    DefaultConnectionGene(key=(-25, 0), weight=-0.5217965841293335, enabled=True)
# (-27, 0)    DefaultConnectionGene(key=(-27, 0), weight=-0.41325443983078003, enabled=False)
# (-28, 0)    DefaultConnectionGene(key=(-28, 0), weight=-0.7347059845924377, enabled=True)
# (-29, 0)    DefaultConnectionGene(key=(-29, 0), weight=-1.0758343935012817, enabled=True)
# (-30, 0)    DefaultConnectionGene(key=(-30, 0), weight=0.1294487863779068, enabled=False)
# (-23, 0)    DefaultConnectionGene(key=(-23, 0), weight=-2.1757988929748535, enabled=True)
# (-18, 0)    DefaultConnectionGene(key=(-18, 0), weight=-0.32294169068336487, enabled=True)
# (-16, 208)    DefaultConnectionGene(key=(-16, 208), weight=1.0, enabled=True)
# (208, 0)    DefaultConnectionGene(key=(208, 0), weight=-0.688518226146698, enabled=False)
# (-9, 208)    DefaultConnectionGene(key=(-9, 208), weight=-0.9244194030761719, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.366
# Mean genetic distance 2.945, standard deviation 1.626
# Population of 50 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    14      4.5    0.540     0
#      2   11    19      6.6    0.779     0
#      3   11    13      4.2    0.494     2
#      4   11     2      0.2    0.018     8
#      5   11     2      0.1    0.000    10
# Total extinctions: 0
# Generation time: 568.665 sec (563.092 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-11
#
#  ****** Running generation 12 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.1451, grad_fn=<DivBackward0>)
# Population's average fitness: 4.11627 stdev: 1.88445
# Best fitness: 6.89085 - size: (2, 24) - species 2 - id 532
# ending generation %s
# Average adjusted fitness: 0.375
# Mean genetic distance 3.026, standard deviation 1.616
# Population of 50 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    14      4.5    0.538     1
#      2   12    20      6.9    0.858     0
#      3   12    12      4.2    0.447     0
#      4   12     2      0.2    0.024     9
#      5   12     2      0.1    0.007    11
# Total extinctions: 0
# Generation time: 574.328 sec (562.259 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-12
#
#  ****** Running generation 13 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.1451, grad_fn=<DivBackward0>)
# Population's average fitness: 4.03519 stdev: 1.90498
# Best fitness: 6.89085 - size: (2, 24) - species 2 - id 532
# ending generation %s
# Average adjusted fitness: 0.361
# Mean genetic distance 3.044, standard deviation 1.599
# Population of 51 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    13      4.5    0.501     2
#      2   13    21      6.9    0.810     1
#      3   13    13      4.2    0.476     1
#      4   13     2      0.2    0.017    10
#      5   13     2      0.1    0.000    12
# Total extinctions: 0
# Generation time: 561.870 sec (559.323 average)
# Saving checkpoint to ./../../data/experiments/breast-cancer/experiment-epochsgpu-10-0/checkpoint-13
#
#  ****** Running generation 14 ******
