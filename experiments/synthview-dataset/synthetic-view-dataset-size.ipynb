# %%
from __future__ import print_function
import os
import neat

import pandas as pd
import numpy as np
import random

import torch
import torch.nn as nn
import torch.optim as optim


from explaneat.core.backprop import NeatNet
from explaneat.core import backprop
from explaneat.core.backproppop import BackpropPopulation
from explaneat.visualization import visualize
from explaneat.core.experiment import ExperimentReporter
from explaneat.core.utility import one_hot_encode


from sklearn import datasets
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


from copy import deepcopy

import time
from datetime import datetime


import gzip
try:
    import cPickle as pickle  # pylint: disable=import-error
except ImportError:
    import pickle  # pylint: disable=import-error

# %%
# USE_CUDA = torch.cuda.is_available()
USE_CUDA = False
device = torch.device("cuda:1" if USE_CUDA else "cpu")

# %% [markdown]
# # Breast Cancer Experiment
#
# This experiment (a) test the experimental environment, but is also to evaluate the efficacy of the ExplaNEAT algorithm. Speed is a critical factor, as well as stability of results on population size. Total run time will also be measured

# %% [markdown]
# First, we need to set a random seed and a total stopping point in the number of generations

# %%
my_random_seed = 42
random.seed(my_random_seed)

# %%
def one_hot_encode(vals):
    width = max(vals)
    newVals = []
    for val in vals:
        blank = [0. for _ in range(width + 1)]
        blank[val] = 1.
        newVals.append(blank)
    return np.asarray(newVals)

# %% [markdown]
# ## Dataset
#
# We are going to work with the Iris dataset, which will be loaded from `sklearn`. We want to characterise the efficacy of the algorithm with regards to a mostly untransformed dataset, so we will only normalise the features

# %%
def load_dataset(fp, 
                 randomSeed = 42, 
                 proportionValidation = 0.2):
    ''' Takes in a filepath, returns x_train, x_validate, y_train, y_validate'''
    df = pd.read_csv(fp).reset_index(drop=True)
    xs_raw = df[[
        'ag_age',
        'ag_sex',
        'ag_eth',
        'pt_nzdep',
        'imp_hxdiab',
        'pt_tc_hdl_ratio',
        'pt_bps',
        'pt_bpd',
        'pt_smoke',
        'imp_hxcvd',
        'imp_hdl',
        'imp_ldl',
        'imp_tchol',
        'marker',
        'region',
        'PH_BL_LLD_ANY',
        'PH_BL_AHT_ANY',
        'pt_familyhistory',
        'ab_gen',
        'eth_gen',
        'is.female',
        'log.age',
        'log.age.gender',
        'log.sbp',
        'smoking',
        'log.tchdl',
        'diabetes',
        'diabetes.sex']]
    
    xs_raw = xs_raw[[
        'is.female', 
        'ag_age',
        'pt_bps',
        'smoking',
        'pt_tc_hdl_ratio',
        'diabetes'
    ]]


    scaler = StandardScaler()
    
    scaler.fit(xs_raw)
    xs = scaler.transform(xs_raw)
    ys = df['dead'].apply(lambda x: 1 if x else 0)
    ys = np.array(ys).astype(float)
    if proportionValidation == 0:
        return xs, [], ys, []
    X_train, X_validate, y_train, y_validate = train_test_split(xs, ys, test_size=proportionValidation, random_state=randomSeed)
    return X_train, X_validate, y_train, y_validate

# %%
X_test, _, y_test, __ = load_dataset('./../../data/processed/synthetic_view/synthetic_view_test.csv')

# %%
X_test[:5]
# Out:
# array([[-1.04660448, -0.79372918, -0.82597264, -0.86593193, -2.14787211,
#         -0.3018414 ],
#        [-1.04660448, -1.54731757,  0.1902044 ,  1.15482518, -0.0411511 ,
#         -0.3018414 ],
#        [-1.04660448,  0.51355442,  0.03688167,  1.15482518, -0.10389362,
#         -0.3018414 ],
#        [ 0.95547078, -0.86687438, -1.44050974, -0.86593193, -0.10620131,
#         -0.3018414 ],
#        [ 0.95547078,  0.99632167, -0.82704809, -0.86593193, -0.8058885 ,
#         -0.3018414 ]])

# %%
y_test[:5]
# Out:
# array([0., 0., 0., 0., 0.])

# %% [markdown]
# ## Performance metric
#
# The NEAT implementation on which ExplaNEAT extends uses a single function call for evaluating fitness. Although this might be reworked for ExplaNEAT to be able to get consistency between the genome-evaluation and the backprop loss function, that can be reviewed later.
#
# This use `Binary Cross Entropy Loss` from `PyTorch`

# %%
# def eval_genomes(genomes, config):
#     loss = nn.BCELoss()
#     loss = loss.to(device)
#     for genome_id, genome in genomes:
#         net = neat.nn.FeedForwardNetwork.create(genome, config)
#         preds = []
#         for xi in X_validate:
#             preds.append(1. if net.activate(xi)[0] > 0.5 else 0.)
#         correct = 0
#         for pred, truth in zip(preds, y_validate):
#             if pred == truth:
#                 correct += 1.
        
        
#         genome.fitness = float(correct / len(preds))
def eval_genomes(genomes, config):
    loss = nn.BCELoss()
    loss = loss.to(device)
    for genome_id, genome in genomes:
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        preds = []
        for xi in X_validate:
            preds.append(net.activate(xi))
        genome.fitness = float(1./loss(torch.tensor(preds), torch.tensor(y_validate)))

# %% [markdown]
# ## Base configuration
#
# We are going to create the base configuration according to an external configuration file. Per experiment, we will adjust this, later, but this defines the defaults across all runs.

# %%
config_path = "./config-synthview"
base_config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     config_path)

# %%
base_config.pop_size
# Out:
# 50

# %% [markdown]
# We also want to put a hard limit on how long this can go on for.

# %%
maxNGenerations = 100

# %% [markdown]
# We will create a method to manage the instantiation of a population on the basis of a specific config.

# %%
def instantiate_population(config, xs, ys, saveLocation):

    if not os.path.exists(saveLocation):
        os.makedirs(saveLocation)
        
    config.save(os.path.join(saveLocation, 'config.conf'))

    # Create the population, which is the top-level object for a NEAT run.
    p = BackpropPopulation(config, 
                            xs, 
                            ys, 
                            criterion=nn.BCELoss())

    # Add a stdout reporter to show progress in the terminal.
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)
    p.add_reporter(neat.Checkpointer(5, filename_prefix=str(saveLocation) + "checkpoint-" ))
    bpReporter = backprop.BackpropReporter(True)
    p.add_reporter(bpReporter)
    p.add_reporter(ExperimentReporter(saveLocation))
    
    return p

# %% [markdown]
# # Experiment: Vary dataset size
#
# The first experiment is going to examine the difference from different dataset sizess

# %%
datasetSizes = [
        1000,
#         2500,
#         5000,
#         10000,
#         25000,
#         50000,
#         100000,
        250000,
#         500000,
#         1000000,
#         1500000,
#         2000000
    ]
# datasetSizes = [1000]

# %%
base_config.pop_size
# Out:
# 50

# %%
saveLocationTemplate = './../../data/experiments/synthview/experiment-dataset-{}-{}/'

# %%
datasetLocation = './../../data/processed/synthetic_view/'
datasetFileTemplate = 'synthetic_view_test_{:07d}.csv'
# os.path.join(output_filepath, 'synthetic_view_test_{:07d}.csv'.format(dsSize)))

# %%
X_train, X_validate, y_train, y_validate = load_dataset(os.path.join(datasetLocation, datasetFileTemplate.format(1000)))

# %%
X_train[:5]
# Out:
# array([[ 0.96462528, -0.53797002, -0.9557672 ,  1.1560487 ,  0.48886043,
#         -0.31831052],
#        [-1.03667198,  1.76174535, -0.44512965, -0.86501546, -0.77320438,
#          3.14158642],
#        [-1.03667198,  0.08111723,  0.07925572, -0.86501546, -0.27909074,
#         -0.31831052],
#        [ 0.96462528, -0.03319542,  0.30570823,  1.1560487 , -0.8926339 ,
#         -0.31831052],
#        [ 0.96462528, -1.25741506, -1.46179745, -0.86501546, -1.27272262,
#         -0.31831052]])

# %%
y_train[:5]
# Out:
# array([1., 0., 0., 0., 0.])

# %% [markdown]
# ## Start the experiment

# %%
for dsSize in datasetSizes:
    for iteration_no in range(5):
        
        X_train, X_validate, y_train, y_validate = load_dataset(os.path.join(datasetLocation, datasetFileTemplate.format(dsSize)))
        X_train = torch.tensor(X_train)
        X_validate = torch.tensor(X_validate)
        y_train = torch.tensor(y_train).float()
        y_validate = torch.tensor(y_validate).float()
        
        
        my_random_seed += 1
        random.seed(my_random_seed)
        start_time = datetime.now()
        
        print("################################################")
        print("################################################")
        print("Starting dsSize {} iteration {}".format(dsSize, iteration_no))
        print("Started at {}".format(start_time.strftime("%m/%d/%Y, %H:%M:%S")))
        print("################################################")
        print("################################################")
        
        
        config = deepcopy(base_config)
        
        saveLocation = saveLocationTemplate.format(dsSize, iteration_no)
        
        p = instantiate_population(config, X_train, y_train, saveLocation)
        # Run for up to nGenerations generations.
        winner = p.run(eval_genomes, maxNGenerations, nEpochs = 10)
        
        g = p.best_genome

        
        end_time = datetime.now()
        
        p.reporters.reporters[2].save_checkpoint(p.config, p.population, p.species, str(p.generation) + "-final")  
        
        winner_net = neat.nn.FeedForwardNetwork.create(winner, config)

        results = []
        for xi, xo in zip(X_test, y_test):
            output = winner_net.activate(xi)
            results.append([xi, xo, output])

        df = pd.DataFrame(results)
        df.to_csv(os.path.join(saveLocation, 'results.csv'))
        
        ancestry = p.reporters.reporters[3].trace_ancestry_of_species(g.key, p.reproduction.ancestors) 

        ancestors = {
            k: v['genome'] for k, v in p.reporters.reporters[3].ancestry.items()
        }
        
        
        
        ## Save all of these to disc
        filename = 'fullStatus.xplnt'
        print("Saving checkpoint to {0}".format(filename))

        with gzip.open(os.path.join(saveLocation, filename), 'w', compresslevel=5) as f:
            data = (p, g, ancestry, ancestors, random.getstate())
            pickle.dump(data, f, protocol=pickle.HIGHEST_PROTOCOL)
    
#         visualize.create_ancestry_video(p.config, 
#                                         g, 
#                                         ancestry, 
#                                         ancestors, 
#                                         p.reporters.reporters[1], 
#                                         pathname=saveLocation)
        print("################################################")
        print("################################################")
        print("Have finished dsSize {} iteration {}".format(dsSize, iteration_no))
        print("Started at {}".format(start_time.strftime("%m/%d/%Y, %H:%M:%S")))
        print("The time is {}".format(end_time.strftime("%m/%d/%Y, %H:%M:%S")))
        print("################################################")
        print("################################################")
# Out:
# ################################################
# ################################################
# Starting dsSize 1000 iteration 0
# Started at 07/26/2019, 03:09:23
# ################################################
# ################################################
#
#  ****** Running generation 0 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(1.2052, grad_fn=<DivBackward0>)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:2016: UserWarning: Using a target size (torch.Size([200])) that is different to the input size (torch.Size([200, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Population's average fitness: 0.25705 stdev: 0.18992
# Best fitness: 1.23191 - size: (1, 6) - species 4 - id 32
# ending generation %s
# Average adjusted fitness: 0.253
# Mean genetic distance 3.591, standard deviation 1.730
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     5      0.1    0.021     0
#      2    0     8      0.8    0.289     0
#      3    0    17      0.5    0.125     0
#      4    0    20      1.2    0.578     0
# Total extinctions: 0
# Generation time: 95.575 sec
#
#  ****** Running generation 1 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.5804, grad_fn=<DivBackward0>)
# Population's average fitness: 0.64215 stdev: 0.46562
# Best fitness: 1.97409 - size: (2, 7) - species 4 - id 90
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f86661c7dd8>, 'fitness': 1.974089503288269, 'firstDerivatives': [0.0, 0.7421772480010986], 'secondDerivatives': [0.0, 0.7421772480010986]}
# Key: 90
# Fitness: 1.974089503288269
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-2.4309751987457275, response=1.0, activation=sigmoid, aggregation=sum)
# 	24 DefaultNodeGene(key=24, bias=0.11454449594020844, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-6, 0), weight=-1.1992640495300293, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=1.4717118740081787, enabled=False)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.25859564542770386, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-0.14437325298786163, enabled=True)
# 	DefaultConnectionGene(key=(-3, 24), weight=0.22507493197917938, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.3214797079563141, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=-0.2615860402584076, enabled=True)
# 	DefaultConnectionGene(key=(24, 0), weight=1.4717118740081787, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=-2.4309751987457275, response=1.0, activation=sigmoid, aggregation=sum)
# 24    DefaultNodeGene(key=24, bias=0.11454449594020844, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-1, 0)    DefaultConnectionGene(key=(-1, 0), weight=-0.2615860402584076, enabled=True)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=0.3214797079563141, enabled=True)
# (-3, 0)    DefaultConnectionGene(key=(-3, 0), weight=-0.14437325298786163, enabled=True)
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=0.25859564542770386, enabled=True)
# (-5, 0)    DefaultConnectionGene(key=(-5, 0), weight=1.4717118740081787, enabled=False)
# (-6, 0)    DefaultConnectionGene(key=(-6, 0), weight=-1.1992640495300293, enabled=True)
# (24, 0)    DefaultConnectionGene(key=(24, 0), weight=1.4717118740081787, enabled=True)
# (-3, 24)    DefaultConnectionGene(key=(-3, 24), weight=0.22507493197917938, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.226
# Mean genetic distance 3.067, standard deviation 1.276
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1     3      0.2    0.007     0
#      2    1     6      1.6    0.327     0
#      3    1    11      0.7    0.141     0
#      4    1    30      2.0    0.430     0
# Total extinctions: 0
# Generation time: 95.790 sec (95.682 average)
#
#  ****** Running generation 2 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.3075, grad_fn=<DivBackward0>)
# Population's average fitness: 1.10689 stdev: 0.67563
# Best fitness: 3.20253 - size: (2, 4) - species 2 - id 114
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f8665526a20>, 'fitness': 3.2025344371795654, 'firstDerivatives': [0.0, 0.7421772480010986, 1.2284449338912964], 'secondDerivatives': [0.0, 0.7421772480010986, 0.48626768589019775]}
# Key: 114
# Fitness: 3.2025344371795654
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 	41 DefaultNodeGene(key=41, bias=-0.040160950273275375, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-6, 0), weight=0.2846299111843109, enabled=False)
# 	DefaultConnectionGene(key=(-6, 41), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=0.09309050440788269, enabled=False)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=0.17415738105773926, enabled=True)
# 	DefaultConnectionGene(key=(41, 0), weight=0.2846299111843109, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 41    DefaultNodeGene(key=41, bias=-0.040160950273275375, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-1, 0)    DefaultConnectionGene(key=(-1, 0), weight=0.17415738105773926, enabled=True)
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=True)
# (-5, 0)    DefaultConnectionGene(key=(-5, 0), weight=0.09309050440788269, enabled=False)
# (-6, 0)    DefaultConnectionGene(key=(-6, 0), weight=0.2846299111843109, enabled=False)
# (-6, 41)    DefaultConnectionGene(key=(-6, 41), weight=1.0, enabled=True)
# (41, 0)    DefaultConnectionGene(key=(41, 0), weight=0.2846299111843109, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.265
# Mean genetic distance 2.921, standard deviation 1.258
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2     2      0.5    0.034     0
#      2    2    16      3.2    0.537     0
#      3    2     9      0.8    0.137     0
#      4    2    23      2.6    0.353     0
# Total extinctions: 0
# Generation time: 103.046 sec (98.137 average)
#
#  ****** Running generation 3 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2955, grad_fn=<DivBackward0>)
# Population's average fitness: 1.92074 stdev: 1.01045
# Best fitness: 3.72686 - size: (2, 4) - species 2 - id 164
# ending generation %s
# Average adjusted fitness: 0.370
# Mean genetic distance 2.679, standard deviation 1.220
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3     2      0.5    0.044     1
#      2    3    21      3.7    0.769     0
#      3    3     8      2.1    0.227     0
#      4    3    19      3.1    0.442     0
# Total extinctions: 0
# Generation time: 107.232 sec (100.411 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-3
#
#  ****** Running generation 4 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2732, grad_fn=<DivBackward0>)
# Population's average fitness: 2.37741 stdev: 1.10252
# Best fitness: 3.72686 - size: (2, 4) - species 2 - id 164
# ending generation %s
# Average adjusted fitness: 0.467
# Mean genetic distance 2.669, standard deviation 1.145
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4     2      0.5    0.044     2
#      2    4    24      3.7    0.795     1
#      3    4     8      3.0    0.487     0
#      4    4    16      3.1    0.544     1
# Total extinctions: 0
# Generation time: 108.423 sec (102.013 average)
#
#  ****** Running generation 5 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2833, grad_fn=<DivBackward0>)
# Population's average fitness: 2.58419 stdev: 1.11023
# Best fitness: 3.72686 - size: (2, 4) - species 2 - id 164
# ending generation %s
# Average adjusted fitness: 0.504
# Mean genetic distance 2.629, standard deviation 1.075
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5     2      0.5    0.044     3
#      2    5    22      3.7    0.822     2
#      3    5    11      3.0    0.536     1
#      4    5    15      3.4    0.613     0
# Total extinctions: 0
# Generation time: 115.233 sec (104.217 average)
#
#  ****** Running generation 6 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2651, grad_fn=<DivBackward0>)
# Population's average fitness: 2.66728 stdev: 1.16761
# Best fitness: 3.78189 - size: (3, 6) - species 2 - id 292
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f8665504860>, 'fitness': 3.7818915843963623, 'firstDerivatives': [0.0, 0.7421772480010986, 1.2284449338912964, 0.5243299007415771, 0.0, 0.0, 0.05502724647521973], 'secondDerivatives': [0.0, 0.7421772480010986, 0.48626768589019775, -0.7041150331497192, -0.5243299007415771, 0.0, 0.05502724647521973]}
# Key: 292
# Fitness: 3.7818915843963623
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 	35 DefaultNodeGene(key=35, bias=-0.06967528909444809, response=1.0, activation=sigmoid, aggregation=sum)
# 	130 DefaultNodeGene(key=130, bias=-0.8311375975608826, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-6, 0), weight=0.2846299111843109, enabled=False)
# 	DefaultConnectionGene(key=(-6, 35), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=True)
# 	DefaultConnectionGene(key=(-4, 35), weight=-1.3738435506820679, enabled=True)
# 	DefaultConnectionGene(key=(-1, 35), weight=-0.5580098628997803, enabled=True)
# 	DefaultConnectionGene(key=(35, 0), weight=0.2846299111843109, enabled=False)
# 	DefaultConnectionGene(key=(35, 130), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(130, 0), weight=0.2846299111843109, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 35    DefaultNodeGene(key=35, bias=-0.06967528909444809, response=1.0, activation=sigmoid, aggregation=sum)
# 130    DefaultNodeGene(key=130, bias=-0.8311375975608826, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=True)
# (-6, 0)    DefaultConnectionGene(key=(-6, 0), weight=0.2846299111843109, enabled=False)
# (-6, 35)    DefaultConnectionGene(key=(-6, 35), weight=1.0, enabled=True)
# (35, 0)    DefaultConnectionGene(key=(35, 0), weight=0.2846299111843109, enabled=False)
# (-4, 35)    DefaultConnectionGene(key=(-4, 35), weight=-1.3738435506820679, enabled=True)
# (35, 130)    DefaultConnectionGene(key=(35, 130), weight=1.0, enabled=True)
# (130, 0)    DefaultConnectionGene(key=(130, 0), weight=0.2846299111843109, enabled=True)
# (-1, 35)    DefaultConnectionGene(key=(-1, 35), weight=-0.5580098628997803, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.525
# Mean genetic distance 2.512, standard deviation 0.950
# Population of 51 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6     2      0.5    0.043     4
#      2    6    21      3.8    0.816     0
#      3    6    12      3.2    0.532     0
#      4    6    16      3.4    0.711     0
# Total extinctions: 0
# Generation time: 116.321 sec (105.946 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-6
#
#  ****** Running generation 7 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2651, grad_fn=<DivBackward0>)
# Population's average fitness: 2.69559 stdev: 1.15157
# Best fitness: 3.81086 - size: (1, 1) - species 2 - id 336
# ending generation %s
# Average adjusted fitness: 0.533
# Mean genetic distance 2.208, standard deviation 0.986
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7     2      0.5    0.043     5
#      2    7    20      3.8    0.873     0
#      3    7    13      3.2    0.622     1
#      4    7    15      3.4    0.593     0
# Total extinctions: 0
# Generation time: 126.378 sec (108.500 average)
#
#  ****** Running generation 8 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2752, grad_fn=<DivBackward0>)
# Population's average fitness: 2.73958 stdev: 1.22909
# Best fitness: 3.83384 - size: (2, 3) - species 2 - id 382
# ending generation %s
# Average adjusted fitness: 0.551
# Mean genetic distance 2.360, standard deviation 0.869
# Population of 51 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8     2      0.5    0.042     6
#      2    8    21      3.8    0.775     0
#      3    8    12      3.4    0.662     0
#      4    8    16      3.5    0.725     0
# Total extinctions: 0
# Generation time: 119.012 sec (109.668 average)
#
#  ****** Running generation 9 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2689, grad_fn=<DivBackward0>)
# Population's average fitness: 2.69868 stdev: 1.28189
# Best fitness: 3.83384 - size: (2, 3) - species 2 - id 382
# ending generation %s
# Average adjusted fitness: 0.533
# Mean genetic distance 2.386, standard deviation 0.861
# Population of 49 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9     2      0.5    0.042     7
#      2    9    19      3.8    0.807     1
#      3    9    12      3.4    0.590     0
#      4    9    16      3.5    0.692     1
# Total extinctions: 0
# Generation time: 126.397 sec (111.341 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-9
#
#  ****** Running generation 10 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2673, grad_fn=<DivBackward0>)
# Population's average fitness: 2.76251 stdev: 1.29148
# Best fitness: 3.92352 - size: (3, 5) - species 2 - id 470
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f8666234438>, 'fitness': 3.9235217571258545, 'firstDerivatives': [0.0, 0.7421772480010986, 1.2284449338912964, 0.5243299007415771, 0.0, 0.0, 0.05502724647521973, 0.028966665267944336, 0.022984027862548828, 0.0, 0.08967947959899902], 'secondDerivatives': [0.0, 0.7421772480010986, 0.48626768589019775, -0.7041150331497192, -0.5243299007415771, 0.0, 0.05502724647521973, -0.02606058120727539, -0.005982637405395508, -0.022984027862548828, 0.08967947959899902]}
# Key: 470
# Fitness: 3.9235217571258545
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 	170 DefaultNodeGene(key=170, bias=-1.2516673803329468, response=1.0, activation=sigmoid, aggregation=sum)
# 	219 DefaultNodeGene(key=219, bias=1.0025882720947266, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-6, 170), weight=-0.8587177991867065, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=-0.21294112503528595, enabled=False)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# 	DefaultConnectionGene(key=(-4, 170), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# 	DefaultConnectionGene(key=(170, 0), weight=0.08813497424125671, enabled=False)
# 	DefaultConnectionGene(key=(170, 219), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(219, 0), weight=0.08813497424125671, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 170    DefaultNodeGene(key=170, bias=-1.2516673803329468, response=1.0, activation=sigmoid, aggregation=sum)
# 219    DefaultNodeGene(key=219, bias=1.0025882720947266, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# (-5, 0)    DefaultConnectionGene(key=(-5, 0), weight=-0.21294112503528595, enabled=False)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# (-4, 170)    DefaultConnectionGene(key=(-4, 170), weight=1.0, enabled=True)
# (170, 0)    DefaultConnectionGene(key=(170, 0), weight=0.08813497424125671, enabled=False)
# (170, 219)    DefaultConnectionGene(key=(170, 219), weight=1.0, enabled=True)
# (219, 0)    DefaultConnectionGene(key=(219, 0), weight=0.08813497424125671, enabled=True)
# (-6, 170)    DefaultConnectionGene(key=(-6, 170), weight=-0.8587177991867065, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.532
# Mean genetic distance 2.488, standard deviation 0.874
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10     2      0.5    0.041     8
#      2   10    20      3.9    0.871     0
#      3   10    13      3.5    0.559     0
#      4   10    15      3.5    0.656     0
# Total extinctions: 0
# Generation time: 128.961 sec (114.679 average)
#
#  ****** Running generation 11 ******
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2673, grad_fn=<DivBackward0>)
# Population's average fitness: 2.71542 stdev: 1.33852
# Best fitness: 3.94362 - size: (3, 5) - species 2 - id 501
# ending generation %s
# Average adjusted fitness: 0.535
# Mean genetic distance 2.447, standard deviation 0.945
# Population of 49 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11     2      0.5    0.041     9
#      2   11    16      3.9    0.723     0
#      3   11    17      3.5    0.738     0
#      4   11    14      3.6    0.638     0
# Total extinctions: 0
# Generation time: 138.228 sec (118.923 average)
#
#  ****** Running generation 12 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2662, grad_fn=<DivBackward0>)
# Population's average fitness: 2.48737 stdev: 1.44211
# Best fitness: 3.94362 - size: (3, 5) - species 2 - id 501
# ending generation %s
# Average adjusted fitness: 0.492
# Mean genetic distance 2.504, standard deviation 0.984
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12     2      0.5    0.041    10
#      2   12    17      3.9    0.744     1
#      3   12    15      3.5    0.505     0
#      4   12    16      3.6    0.678     1
# Total extinctions: 0
# Generation time: 143.252 sec (122.944 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-12
#
#  ****** Running generation 13 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2636, grad_fn=<DivBackward0>)
# Population's average fitness: 2.64327 stdev: 1.41900
# Best fitness: 3.94862 - size: (2, 3) - species 2 - id 591
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f86653bb860>, 'fitness': 3.9486184120178223, 'firstDerivatives': [0.0, 0.7421772480010986, 1.2284449338912964, 0.5243299007415771, 0.0, 0.0, 0.05502724647521973, 0.028966665267944336, 0.022984027862548828, 0.0, 0.08967947959899902, 0.02010035514831543, 0.0, 0.004996299743652344], 'secondDerivatives': [0.0, 0.7421772480010986, 0.48626768589019775, -0.7041150331497192, -0.5243299007415771, 0.0, 0.05502724647521973, -0.02606058120727539, -0.005982637405395508, -0.022984027862548828, 0.08967947959899902, -0.0695791244506836, -0.02010035514831543, 0.004996299743652344]}
# Key: 591
# Fitness: 3.9486184120178223
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 	211 DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-3, 211), weight=0.6774719953536987, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# 	DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 211    DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# (211, 0)    DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# (-3, 211)    DefaultConnectionGene(key=(-3, 211), weight=0.6774719953536987, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.515
# Mean genetic distance 2.427, standard deviation 0.987
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13     2      0.5    0.041    11
#      2   13    15      3.9    0.912     0
#      3   13    19      3.5    0.585     1
#      4   13    14      3.6    0.523     0
# Total extinctions: 0
# Generation time: 152.633 sec (127.484 average)
#
#  ****** Running generation 14 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2581, grad_fn=<DivBackward0>)
# Population's average fitness: 2.65166 stdev: 1.42130
# Best fitness: 3.94862 - size: (2, 3) - species 3 - id 591
# ending generation %s
# Average adjusted fitness: 0.527
# Mean genetic distance 2.481, standard deviation 0.946
# Population of 51 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14     2      0.5    0.041    12
#      2   14    22      3.9    0.804     1
#      3   14    12      3.9    0.598     0
#      4   14    15      3.6    0.665     0
# Total extinctions: 0
# Generation time: 140.110 sec (130.653 average)
#
#  ****** Running generation 15 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2683, grad_fn=<DivBackward0>)
# Population's average fitness: 2.81995 stdev: 1.43294
# Best fitness: 3.94905 - size: (4, 7) - species 2 - id 660
# ending generation %s
# Average adjusted fitness: 0.522
# Mean genetic distance 2.297, standard deviation 0.913
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15     2      0.5    0.041    13
#      2   15    16      3.9    0.902     0
#      3   15    16      3.8    0.448     1
#      4   15    16      3.6    0.697     0
# Total extinctions: 0
# Generation time: 144.558 sec (133.585 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-15
#
#  ****** Running generation 16 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2683, grad_fn=<DivBackward0>)
# Population's average fitness: 2.28638 stdev: 1.57394
# Best fitness: 3.94905 - size: (4, 7) - species 2 - id 660
# ending generation %s
# Average adjusted fitness: 0.446
# Mean genetic distance 2.116, standard deviation 0.934
# Population of 51 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16     2      0.5    0.041    14
#      2   16     8      3.9    0.840     1
#      3   16    24      3.9    0.309     2
#      4   16    17      3.6    0.595     0
# Total extinctions: 0
# Generation time: 124.721 sec (134.425 average)
#
#  ****** Running generation 17 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2676, grad_fn=<DivBackward0>)
# Population's average fitness: 2.89007 stdev: 1.39937
# Best fitness: 3.94905 - size: (4, 7) - species 3 - id 660
# ending generation %s
# Average adjusted fitness: 0.582
# Mean genetic distance 2.271, standard deviation 1.006
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17     2      0.5    0.041    15
#      2   17    17      3.9    0.859     2
#      3   17    16      3.9    0.780     0
#      4   17    15      3.6    0.649     1
# Total extinctions: 0
# Generation time: 142.066 sec (135.994 average)
#
#  ****** Running generation 18 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2683, grad_fn=<DivBackward0>)
# Population's average fitness: 2.99892 stdev: 1.31776
# Best fitness: 3.94926 - size: (4, 8) - species 2 - id 791
# ending generation %s
# Average adjusted fitness: 0.590
# Mean genetic distance 2.311, standard deviation 1.098
# Population of 51 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18     2      0.5    0.041    16
#      2   18     3      3.9    0.979     0
#      3   18    30      3.9    0.589     1
#      4   18    16      3.6    0.751     2
# Total extinctions: 0
# Generation time: 146.043 sec (138.697 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-18
#
#  ****** Running generation 19 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2683, grad_fn=<DivBackward0>)
# Population's average fitness: 2.96453 stdev: 1.37624
# Best fitness: 3.94926 - size: (4, 8) - species 3 - id 791
# ending generation %s
# Average adjusted fitness: 0.561
# Mean genetic distance 2.233, standard deviation 1.203
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19     2      0.5    0.041    17
#      2   19    11      3.8    0.671     1
#      3   19    21      3.9    0.793     0
#      4   19    16      3.9    0.738     0
# Total extinctions: 0
# Generation time: 154.047 sec (141.462 average)
#
#  ****** Running generation 20 ******
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2661, grad_fn=<DivBackward0>)
# Population's average fitness: 3.26444 stdev: 1.14972
# Best fitness: 3.96709 - size: (5, 8) - species 3 - id 886
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f8665570f28>, 'fitness': 3.967092275619507, 'firstDerivatives': [0.0, 0.7421772480010986, 1.2284449338912964, 0.5243299007415771, 0.0, 0.0, 0.05502724647521973, 0.028966665267944336, 0.022984027862548828, 0.0, 0.08967947959899902, 0.02010035514831543, 0.0, 0.004996299743652344, 0.0, 0.00042939186096191406, 0.0, 0.0, 0.0002143383026123047, 0.0, 0.01783013343811035], 'secondDerivatives': [0.0, 0.7421772480010986, 0.48626768589019775, -0.7041150331497192, -0.5243299007415771, 0.0, 0.05502724647521973, -0.02606058120727539, -0.005982637405395508, -0.022984027862548828, 0.08967947959899902, -0.0695791244506836, -0.02010035514831543, 0.004996299743652344, -0.004996299743652344, 0.00042939186096191406, -0.00042939186096191406, 0.0, 0.0002143383026123047, -0.0002143383026123047, 0.01783013343811035]}
# Key: 886
# Fitness: 3.967092275619507
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 	170 DefaultNodeGene(key=170, bias=-1.2516673803329468, response=1.0, activation=sigmoid, aggregation=sum)
# 	211 DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# 	292 DefaultNodeGene(key=292, bias=-1.360953688621521, response=1.0, activation=sigmoid, aggregation=sum)
# 	412 DefaultNodeGene(key=412, bias=2.667022228240967, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-5, 211), weight=1.369208574295044, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# 	DefaultConnectionGene(key=(-4, 170), weight=1.0, enabled=False)
# 	DefaultConnectionGene(key=(-4, 292), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(-3, 211), weight=0.6774719953536987, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# 	DefaultConnectionGene(key=(170, 0), weight=0.08813497424125671, enabled=False)
# 	DefaultConnectionGene(key=(170, 211), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# 	DefaultConnectionGene(key=(292, 170), weight=1.0, enabled=False)
# 	DefaultConnectionGene(key=(292, 412), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(412, 170), weight=1.0, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 170    DefaultNodeGene(key=170, bias=-1.2516673803329468, response=1.0, activation=sigmoid, aggregation=sum)
# 211    DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# 292    DefaultNodeGene(key=292, bias=-1.360953688621521, response=1.0, activation=sigmoid, aggregation=sum)
# 412    DefaultNodeGene(key=412, bias=2.667022228240967, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# (-4, 170)    DefaultConnectionGene(key=(-4, 170), weight=1.0, enabled=False)
# (170, 0)    DefaultConnectionGene(key=(170, 0), weight=0.08813497424125671, enabled=False)
# (170, 211)    DefaultConnectionGene(key=(170, 211), weight=1.0, enabled=True)
# (211, 0)    DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# (-3, 211)    DefaultConnectionGene(key=(-3, 211), weight=0.6774719953536987, enabled=True)
# (-4, 292)    DefaultConnectionGene(key=(-4, 292), weight=1.0, enabled=True)
# (292, 170)    DefaultConnectionGene(key=(292, 170), weight=1.0, enabled=False)
# (292, 412)    DefaultConnectionGene(key=(292, 412), weight=1.0, enabled=True)
# (412, 170)    DefaultConnectionGene(key=(412, 170), weight=1.0, enabled=True)
# (-5, 211)    DefaultConnectionGene(key=(-5, 211), weight=1.369208574295044, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.638
# Mean genetic distance 2.345, standard deviation 1.146
# Population of 51 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20     2      0.5    0.041    18
#      2   20    24      3.8    0.786     2
#      3   20     8      4.0    0.877     0
#      4   20    17      3.9    0.850     1
# Total extinctions: 0
# Generation time: 165.282 sec (145.094 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-20
#
#  ****** Running generation 21 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2655, grad_fn=<DivBackward0>)
# Population's average fitness: 3.18449 stdev: 1.24518
# Best fitness: 3.97954 - size: (4, 6) - species 3 - id 925
# ending generation %s
# Average adjusted fitness: 0.595
# Mean genetic distance 2.340, standard deviation 1.065
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21     2      0.5    0.041    19
#      2   21     2      4.0    0.894     0
#      3   21    30      4.0    0.642     0
#      4   21    16      3.9    0.805     0
# Total extinctions: 0
# Generation time: 163.795 sec (147.651 average)
#
#  ****** Running generation 22 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2598, grad_fn=<DivBackward0>)
# Population's average fitness: 2.95028 stdev: 1.41067
# Best fitness: 3.97954 - size: (5, 7) - species 3 - id 958
# ending generation %s
#
# Species 1 with 2 members is stagnated: removing it
# Average adjusted fitness: 0.797
# Mean genetic distance 2.156, standard deviation 1.126
# Population of 49 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   22    11      3.9    0.972     1
#      3   22    23      4.0    0.767     1
#      4   22    15      3.9    0.652     0
# Total extinctions: 0
# Generation time: 173.364 sec (150.662 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-22
#
#  ****** Running generation 23 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2655, grad_fn=<DivBackward0>)
# Population's average fitness: 3.15605 stdev: 1.33231
# Best fitness: 3.97971 - size: (5, 7) - species 3 - id 1004
# ending generation %s
# Average adjusted fitness: 0.773
# Mean genetic distance 2.266, standard deviation 0.909
# Population of 49 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   23    12      3.9    0.883     2
#      3   23    23      4.0    0.775     0
#      4   23    14      3.9    0.662     1
# Total extinctions: 0
# Generation time: 173.441 sec (152.743 average)
#
#  ****** Running generation 24 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2662, grad_fn=<DivBackward0>)
# Population's average fitness: 3.30771 stdev: 1.23757
# Best fitness: 4.00397 - size: (4, 6) - species 3 - id 1048
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f86651efdd8>, 'fitness': 4.003968238830566, 'firstDerivatives': [0.0, 0.7421772480010986, 1.2284449338912964, 0.5243299007415771, 0.0, 0.0, 0.05502724647521973, 0.028966665267944336, 0.022984027862548828, 0.0, 0.08967947959899902, 0.02010035514831543, 0.0, 0.004996299743652344, 0.0, 0.00042939186096191406, 0.0, 0.0, 0.0002143383026123047, 0.0, 0.01783013343811035, 0.01244974136352539, 0.0, 0.0001647472381591797, 0.024261474609375], 'secondDerivatives': [0.0, 0.7421772480010986, 0.48626768589019775, -0.7041150331497192, -0.5243299007415771, 0.0, 0.05502724647521973, -0.02606058120727539, -0.005982637405395508, -0.022984027862548828, 0.08967947959899902, -0.0695791244506836, -0.02010035514831543, 0.004996299743652344, -0.004996299743652344, 0.00042939186096191406, -0.00042939186096191406, 0.0, 0.0002143383026123047, -0.0002143383026123047, 0.01783013343811035, -0.005380392074584961, -0.01244974136352539, 0.0001647472381591797, 0.02409672737121582]}
# Key: 1048
# Fitness: 4.003968238830566
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 	211 DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# 	292 DefaultNodeGene(key=292, bias=-1.360953688621521, response=1.0, activation=sigmoid, aggregation=sum)
# 	428 DefaultNodeGene(key=428, bias=-0.1434708684682846, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-5, 211), weight=1.369208574295044, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# 	DefaultConnectionGene(key=(-4, 211), weight=0.8454371094703674, enabled=True)
# 	DefaultConnectionGene(key=(-4, 292), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(-4, 428), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# 	DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 211    DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# 292    DefaultNodeGene(key=292, bias=-1.360953688621521, response=1.0, activation=sigmoid, aggregation=sum)
# 428    DefaultNodeGene(key=428, bias=-0.1434708684682846, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# (211, 0)    DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# (-4, 292)    DefaultConnectionGene(key=(-4, 292), weight=1.0, enabled=True)
# (-5, 211)    DefaultConnectionGene(key=(-5, 211), weight=1.369208574295044, enabled=True)
# (-4, 428)    DefaultConnectionGene(key=(-4, 428), weight=1.0, enabled=True)
# (-4, 211)    DefaultConnectionGene(key=(-4, 211), weight=0.8454371094703674, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.815
# Mean genetic distance 2.212, standard deviation 0.958
# Population of 49 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   24    15      4.0    0.888     3
#      3   24    19      4.0    0.763     0
#      4   24    15      4.0    0.793     0
# Total extinctions: 0
# Generation time: 158.880 sec (154.620 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-24
#
#  ****** Running generation 25 ******
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2586, grad_fn=<DivBackward0>)
# Population's average fitness: 3.34943 stdev: 1.21884
# Best fitness: 4.00397 - size: (4, 6) - species 3 - id 1048
# ending generation %s
# Average adjusted fitness: 0.808
# Mean genetic distance 2.021, standard deviation 1.090
# Population of 51 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   25    19      4.0    0.847     4
#      3   25    17      4.0    0.881     1
#      4   25    15      4.0    0.697     1
# Total extinctions: 0
# Generation time: 169.833 sec (157.147 average)
#
#  ****** Running generation 26 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2591, grad_fn=<DivBackward0>)
# Population's average fitness: 3.29401 stdev: 1.24262
# Best fitness: 4.00397 - size: (4, 6) - species 3 - id 1048
# ending generation %s
# Average adjusted fitness: 0.798
# Mean genetic distance 2.020, standard deviation 1.204
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   26    17      4.0    0.709     5
#      3   26    19      4.0    0.977     2
#      4   26    14      4.0    0.709     0
# Total extinctions: 0
# Generation time: 171.487 sec (161.824 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-26
#
#  ****** Running generation 27 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2586, grad_fn=<DivBackward0>)
# Population's average fitness: 3.20130 stdev: 1.31126
# Best fitness: 4.00397 - size: (3, 5) - species 3 - id 1096
# ending generation %s
# Average adjusted fitness: 0.772
# Mean genetic distance 2.144, standard deviation 1.265
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   27    15      4.0    0.631     6
#      3   27    20      4.0    0.938     3
#      4   27    15      4.0    0.748     1
# Total extinctions: 0
# Generation time: 160.595 sec (163.677 average)
#
#  ****** Running generation 28 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2655, grad_fn=<DivBackward0>)
# Population's average fitness: 3.22203 stdev: 1.26980
# Best fitness: 4.00630 - size: (3, 5) - species 3 - id 1233
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f86650b19b0>, 'fitness': 4.0063042640686035, 'firstDerivatives': [0.0, 0.7421772480010986, 1.2284449338912964, 0.5243299007415771, 0.0, 0.0, 0.05502724647521973, 0.028966665267944336, 0.022984027862548828, 0.0, 0.08967947959899902, 0.02010035514831543, 0.0, 0.004996299743652344, 0.0, 0.00042939186096191406, 0.0, 0.0, 0.0002143383026123047, 0.0, 0.01783013343811035, 0.01244974136352539, 0.0, 0.0001647472381591797, 0.024261474609375, 0.0, 0.0, 0.0, 0.0023360252380371094], 'secondDerivatives': [0.0, 0.7421772480010986, 0.48626768589019775, -0.7041150331497192, -0.5243299007415771, 0.0, 0.05502724647521973, -0.02606058120727539, -0.005982637405395508, -0.022984027862548828, 0.08967947959899902, -0.0695791244506836, -0.02010035514831543, 0.004996299743652344, -0.004996299743652344, 0.00042939186096191406, -0.00042939186096191406, 0.0, 0.0002143383026123047, -0.0002143383026123047, 0.01783013343811035, -0.005380392074584961, -0.01244974136352539, 0.0001647472381591797, 0.02409672737121582, -0.024261474609375, 0.0, 0.0, 0.0023360252380371094]}
# Key: 1233
# Fitness: 4.0063042640686035
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 	211 DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# 	292 DefaultNodeGene(key=292, bias=-1.360953688621521, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-6, 211), weight=-0.5201806426048279, enabled=True)
# 	DefaultConnectionGene(key=(-5, 211), weight=1.369208574295044, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# 	DefaultConnectionGene(key=(-3, 292), weight=-1.8971397876739502, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# 	DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 211    DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# 292    DefaultNodeGene(key=292, bias=-1.360953688621521, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# (211, 0)    DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# (-5, 211)    DefaultConnectionGene(key=(-5, 211), weight=1.369208574295044, enabled=True)
# (-3, 292)    DefaultConnectionGene(key=(-3, 292), weight=-1.8971397876739502, enabled=True)
# (-6, 211)    DefaultConnectionGene(key=(-6, 211), weight=-0.5201806426048279, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.760
# Mean genetic distance 2.067, standard deviation 1.266
# Population of 51 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   28    18      4.0    0.712     7
#      3   28    19      4.0    0.934     0
#      4   28    14      4.0    0.634     2
# Total extinctions: 0
# Generation time: 154.146 sec (164.487 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-28
#
#  ****** Running generation 29 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2585, grad_fn=<DivBackward0>)
# Population's average fitness: 3.22512 stdev: 1.27403
# Best fitness: 4.00777 - size: (4, 7) - species 3 - id 1284
# ending generation %s
# Average adjusted fitness: 0.776
# Mean genetic distance 2.161, standard deviation 1.193
# Population of 49 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   29    16      4.0    0.698     8
#      3   29    18      4.0    0.857     0
#      4   29    15      4.0    0.773     0
# Total extinctions: 0
# Generation time: 161.959 sec (165.278 average)
#
#  ****** Running generation 30 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2582, grad_fn=<DivBackward0>)
# Population's average fitness: 2.70294 stdev: 1.60515
# Best fitness: 4.02389 - size: (4, 8) - species 3 - id 1324
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f866513a438>, 'fitness': 4.023888111114502, 'firstDerivatives': [0.0, 0.7421772480010986, 1.2284449338912964, 0.5243299007415771, 0.0, 0.0, 0.05502724647521973, 0.028966665267944336, 0.022984027862548828, 0.0, 0.08967947959899902, 0.02010035514831543, 0.0, 0.004996299743652344, 0.0, 0.00042939186096191406, 0.0, 0.0, 0.0002143383026123047, 0.0, 0.01783013343811035, 0.01244974136352539, 0.0, 0.0001647472381591797, 0.024261474609375, 0.0, 0.0, 0.0, 0.0023360252380371094, 0.001461029052734375, 0.016122817993164062], 'secondDerivatives': [0.0, 0.7421772480010986, 0.48626768589019775, -0.7041150331497192, -0.5243299007415771, 0.0, 0.05502724647521973, -0.02606058120727539, -0.005982637405395508, -0.022984027862548828, 0.08967947959899902, -0.0695791244506836, -0.02010035514831543, 0.004996299743652344, -0.004996299743652344, 0.00042939186096191406, -0.00042939186096191406, 0.0, 0.0002143383026123047, -0.0002143383026123047, 0.01783013343811035, -0.005380392074584961, -0.01244974136352539, 0.0001647472381591797, 0.02409672737121582, -0.024261474609375, 0.0, 0.0, 0.0023360252380371094, -0.0008749961853027344, 0.014661788940429688]}
# Key: 1324
# Fitness: 4.023888111114502
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 	211 DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# 	292 DefaultNodeGene(key=292, bias=-1.360953688621521, response=1.0, activation=sigmoid, aggregation=sum)
# 	627 DefaultNodeGene(key=627, bias=-0.8632059097290039, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-6, 211), weight=-0.5201806426048279, enabled=True)
# 	DefaultConnectionGene(key=(-5, 211), weight=1.369208574295044, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# 	DefaultConnectionGene(key=(-4, 627), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(-3, 292), weight=-1.8971397876739502, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# 	DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# 	DefaultConnectionGene(key=(292, 627), weight=-1.3340853452682495, enabled=True)
# 	DefaultConnectionGene(key=(627, 0), weight=0.08813497424125671, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 211    DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# 292    DefaultNodeGene(key=292, bias=-1.360953688621521, response=1.0, activation=sigmoid, aggregation=sum)
# 627    DefaultNodeGene(key=627, bias=-0.8632059097290039, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# (211, 0)    DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# (-5, 211)    DefaultConnectionGene(key=(-5, 211), weight=1.369208574295044, enabled=True)
# (-3, 292)    DefaultConnectionGene(key=(-3, 292), weight=-1.8971397876739502, enabled=True)
# (-6, 211)    DefaultConnectionGene(key=(-6, 211), weight=-0.5201806426048279, enabled=True)
# (-4, 627)    DefaultConnectionGene(key=(-4, 627), weight=1.0, enabled=True)
# (627, 0)    DefaultConnectionGene(key=(627, 0), weight=0.08813497424125671, enabled=True)
# (292, 627)    DefaultConnectionGene(key=(292, 627), weight=-1.3340853452682495, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.622
# Mean genetic distance 2.236, standard deviation 1.157
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   30    14      4.0    0.375     9
#      3   30    20      4.0    0.868     0
#      4   30    16      4.0    0.622     1
# Total extinctions: 0
# Generation time: 147.423 sec (163.492 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-30
#
#  ****** Running generation 31 ******
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2569, grad_fn=<DivBackward0>)
# Population's average fitness: 3.06863 stdev: 1.36852
# Best fitness: 4.02389 - size: (4, 8) - species 3 - id 1324
# ending generation %s
# Average adjusted fitness: 0.710
# Mean genetic distance 2.293, standard deviation 1.136
# Population of 51 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   31    14      4.0    0.628    10
#      3   31    22      4.0    0.928     1
#      4   31    15      4.0    0.573     2
# Total extinctions: 0
# Generation time: 155.952 sec (162.708 average)
#
#  ****** Running generation 32 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2558, grad_fn=<DivBackward0>)
# Population's average fitness: 3.39546 stdev: 1.15423
# Best fitness: 4.02499 - size: (4, 8) - species 3 - id 1400
#
#
#  SPECIES TOPOLOGY IMPROVEMENT
#
#
# {'genome': <neat.genome.DefaultGenome object at 0x7f8664fae2e8>, 'fitness': 4.024989128112793, 'firstDerivatives': [0.0, 0.7421772480010986, 1.2284449338912964, 0.5243299007415771, 0.0, 0.0, 0.05502724647521973, 0.028966665267944336, 0.022984027862548828, 0.0, 0.08967947959899902, 0.02010035514831543, 0.0, 0.004996299743652344, 0.0, 0.00042939186096191406, 0.0, 0.0, 0.0002143383026123047, 0.0, 0.01783013343811035, 0.01244974136352539, 0.0, 0.0001647472381591797, 0.024261474609375, 0.0, 0.0, 0.0, 0.0023360252380371094, 0.001461029052734375, 0.016122817993164062, 0.0, 0.0011010169982910156], 'secondDerivatives': [0.0, 0.7421772480010986, 0.48626768589019775, -0.7041150331497192, -0.5243299007415771, 0.0, 0.05502724647521973, -0.02606058120727539, -0.005982637405395508, -0.022984027862548828, 0.08967947959899902, -0.0695791244506836, -0.02010035514831543, 0.004996299743652344, -0.004996299743652344, 0.00042939186096191406, -0.00042939186096191406, 0.0, 0.0002143383026123047, -0.0002143383026123047, 0.01783013343811035, -0.005380392074584961, -0.01244974136352539, 0.0001647472381591797, 0.02409672737121582, -0.024261474609375, 0.0, 0.0, 0.0023360252380371094, -0.0008749961853027344, 0.014661788940429688, -0.016122817993164062, 0.0011010169982910156]}
# Key: 1400
# Fitness: 4.024989128112793
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 	211 DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# 	292 DefaultNodeGene(key=292, bias=-1.360953688621521, response=1.0, activation=sigmoid, aggregation=sum)
# 	627 DefaultNodeGene(key=627, bias=-0.8632059097290039, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-6, 211), weight=-1.054733157157898, enabled=True)
# 	DefaultConnectionGene(key=(-5, 211), weight=1.369208574295044, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# 	DefaultConnectionGene(key=(-4, 627), weight=1.0, enabled=True)
# 	DefaultConnectionGene(key=(-3, 292), weight=-1.8971397876739502, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# 	DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# 	DefaultConnectionGene(key=(292, 627), weight=-1.3340853452682495, enabled=True)
# 	DefaultConnectionGene(key=(627, 0), weight=0.08813497424125671, enabled=True)
# Nodes
# 0    DefaultNodeGene(key=0, bias=-0.6354101896286011, response=1.0, activation=sigmoid, aggregation=sum)
# 211    DefaultNodeGene(key=211, bias=0.8491372466087341, response=1.0, activation=sigmoid, aggregation=sum)
# 292    DefaultNodeGene(key=292, bias=-1.360953688621521, response=1.0, activation=sigmoid, aggregation=sum)
# 627    DefaultNodeGene(key=627, bias=-0.8632059097290039, response=1.0, activation=sigmoid, aggregation=sum)
# Connections
# (-4, 0)    DefaultConnectionGene(key=(-4, 0), weight=0.08813497424125671, enabled=False)
# (-2, 0)    DefaultConnectionGene(key=(-2, 0), weight=0.12844710052013397, enabled=True)
# (211, 0)    DefaultConnectionGene(key=(211, 0), weight=0.08813497424125671, enabled=True)
# (-5, 211)    DefaultConnectionGene(key=(-5, 211), weight=1.369208574295044, enabled=True)
# (-3, 292)    DefaultConnectionGene(key=(-3, 292), weight=-1.8971397876739502, enabled=True)
# (-6, 211)    DefaultConnectionGene(key=(-6, 211), weight=-1.054733157157898, enabled=True)
# (-4, 627)    DefaultConnectionGene(key=(-4, 627), weight=1.0, enabled=True)
# (627, 0)    DefaultConnectionGene(key=(627, 0), weight=0.08813497424125671, enabled=True)
# (292, 627)    DefaultConnectionGene(key=(292, 627), weight=-1.3340853452682495, enabled=True)
# ending generation %s
# Average adjusted fitness: 0.811
# Mean genetic distance 2.267, standard deviation 1.131
# Population of 51 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   32    15      4.0    0.805    11
#      3   32    20      4.0    0.891     0
#      4   32    16      4.0    0.738     3
# Total extinctions: 0
# Generation time: 174.124 sec (162.784 average)
# Saving checkpoint to ./../../data/experiments/synthview/experiment-dataset-1000-0/checkpoint-32
#
#  ****** Running generation 33 ******
#
# mean improvement: 0.0
# best improvement: tensor(0., grad_fn=<SubBackward0>)
# best loss: tensor(0.2603, grad_fn=<DivBackward0>)
# Population's average fitness: 3.01516 stdev: 1.49584
# Best fitness: 4.02499 - size: (4, 8) - species 3 - id 1400
# ending generation %s
# Average adjusted fitness: 0.710
# Mean genetic distance 2.294, standard deviation 1.112
# Population of 49 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   33    15      4.0    0.665    12
#      3   33    20      4.0    0.879     1
#      4   33    14      4.0    0.587     0
# Total extinctions: 0
# Generation time: 173.893 sec (162.829 average)
#
#  ****** Running generation 34 ******
